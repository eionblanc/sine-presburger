# %%
from best_approximate import *
from decision import *
from plot import *

import numpy as np
import time
from IPython.display import display, Math

# %% [markdown]
# -------------------------------

# %% [markdown]
# ### Example: best approximates under sine

# %%
np.sin(approx(1000,500)), np.sin(1000)
# Out:
# (0.8268456339220814, 0.8268795405320026)

# %%
k = 6
N = 10**k
d = 10**k - 1

start = time.time()
a = approx(N,d)
end = time.time()

display(Math(r'{}|_{} = {}'.format(N, '{'+str(d)+'}', a)))
display(Math(r'\sin({}) \approx {:.4f}, \sin({}) \approx {:.4f}'.format(N, np.sin(N), a, np.sin(a))))
print('runtime: {:.4f}s'.format(end-start))
# Out:
# $\displaystyle 1000000|_{999999} = 146408$
# $\displaystyle \sin(1000000) \approx -0.3500, \sin(146408) \approx -0.3500$
# runtime: 1.0088s

# %%
approximate_mesh(10, vals=[550], zones=[(6,0)])

# %%
approximate_mesh(50,deg1_color='b',deg1_ann=False,
                 vals=[550,50,41],zones=[(50,41)])

# %% [markdown]
# ### Example: best difference approximates under sine

# %%
diff_approx(50,550,100,140)
# Out:
# (70, 109)

# %%
diff_approx_mesh(50,550,100,140)

# %% [markdown]
# ---------------------------

# %% [markdown]
# --------------------------

# %% [markdown]
# ### Example: graphed level sets for removal of linear appearances
#
# $-x_1 + x_2 - 2 < 2\sin(3x_1 + 2x_2 - 1) + \sin(2x_1)$

# %%
L_term = lambda x,y : -x + y - 2
eps = gcd([(1,1),(-1,1)])
cons = L_term(0,0)

osc_Lsin_term = lambda x,y : 2*np.sin(3*x + 2*y - 1) + np.sin(2*x)
R = 3

# %%
level_sets(eps, cons, R, L_term, osc_Lsin_term, flip=True, title=r'$-x_1+x_2-2<2\sin(3x_1+2x_2-1)+\sin(2x_1)$')
